# %% [markdown]
# # 4. Pandas - plotting

# %%
# %pylab inline
from pandas import Series, DataFrame
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## pandas中的繪圖函數

# %% [markdown]
# ### 線型圖

# %%
# Series, DataFrame 的 plot()方法 預設是繪製 線型圖
s = Series(np.random.randn(10).cumsum(), index = np.arange(0, 100, 10))
s.plot()

# %%
# Series的索引會被作為subplot的 X軸，可以使用參數 use_index = False 來禁用該功能
# X軸的刻度可以透過 xticks 和 xlim 選向來調整
# Y軸的刻度可以透過 yticks 和 ylim 選向來調整

# %%
# DataFrame的 plot()方法會在subplot中為每個 column繪製一條線，並自動創建legend
df = DataFrame(np.random.randn(10, 4).cumsum(0), 
               index = np.arange(0, 100, 10), 
               columns = ['A', 'B', 'C', 'D'])
df.tail(3)
# Out:
#            A         B         C         D
# 70 -0.112941  5.007264  0.078494  0.578639
# 80  0.363279  5.084266  1.001456 -0.073209
# 90  0.750751  5.550768 -0.046546 -0.390532

# %%
df.plot()

# %% [markdown]
# ### 柱狀圖

# %%
# 設定 kind = 'bar' 或 'barh' 即可繪製柱狀圖
# Series和 DataFrame的 索引會被當作subplot的 X軸(bar)或 Y軸(barh)

fig, axes = plt.subplots(2, 1)
data = Series(np.random.rand(16), index = list('abcedfghijklmnop'))
data.plot(ax = axes[0], kind = 'bar')
data.plot(ax = axes[1], kind = 'barh')

# %%
df = DataFrame(np.random.rand(6, 4), 
               index = ['one', 'two', 'three', 'four', 'five', 'six'], 
               columns = pd.Index(['A', 'B', 'C', 'D'], name = 'Genus'))
df  
# DataFrame的每一 row的值分為一組
# Out:
# Genus         A         B         C         D
# one    0.277338  0.517728  0.077138  0.775765
# two    0.985869  0.202038  0.199749  0.506026
# three  0.997729  0.011169  0.486689  0.113402
# four   0.078152  0.729975  0.772746  0.812211
# five   0.737897  0.744565  0.580290  0.810740
# six    0.806751  0.295395  0.633450  0.170521

# %%
# DataFrame的每一 row的值分為一組
# columns 索引的 name屬性 被用來做為 legend的標題
df.plot(kind = 'bar')

# %%
# 設定 stacked = True, 可繪製 堆積柱狀圖
df.plot(kind = 'barh', stacked = True)

# %%
s = Series([2, 3, 5, 2, 5, 6, 7, 8, 9, 10, 13, 2, 3, 4, 7, 8, 9, 0, 0, 2, 2, 1])

# 用Series的 value_counts()直接繪製柱狀圖，表達每個數字出現的次數
vc = s.value_counts()
vc.plot(kind = 'bar')

# %%
tips = pd.read_csv('../data/tips.csv')
tips[:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 用 crosstab()方法創建一個 交叉表，預設統計 發生的次數(計數)
party_counts = pd.crosstab(tips.day , tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts.plot(kind = 'bar')

# %%
party_counts = party_counts.ix[:, 2:5]
party_counts.plot(kind = 'bar', stacked = True)

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_counts = party_counts.div(party_counts.sum(1), axis = 0)
party_counts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_counts.sum(1)
# Out:
# day
# Fri     1
# Sat     1
# Sun     1
# Thur    1
# dtype: float64

# %%
party_counts.plot(kind = 'bar', stacked = True)

# %% [markdown]
# ### 直方圖(histogram)和密度圖

# %%
tips = pd.read_csv('../data/tips.csv')
tips[:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 可以用 plot(kind = 'hist') 來繪製直方圖
tips.total_bill.plot(kind = 'hist', bins = 50)
plt.title('total_bill')

# %%
# 也可以用 hist() 來繪製直方圖
tips.total_bill.hist(bins = 50)
plt.title('total_bill')

# %%
# tip比例 直方圖
tip_ratios = (tips.tip / tips.total_bill)
tip_ratios.hist(bins = 50)
plt.title('tip ratio')

# %% [markdown]
# ### 散佈圖(scatter plot)

# %%
macro = pd.read_csv('../data/macrodata.csv')
macro[:5]
# Out:
#    year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959        1  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959        2  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959        3  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959        4  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960        1  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
data[:5]
# Out:
#      cpi     m1  tbilrate  unemp
# 0  28.98  139.7      2.82    5.8
# 1  29.15  141.7      3.08    5.1
# 2  29.35  140.5      3.82    5.3
# 3  29.37  140.0      4.33    5.6
# 4  29.54  139.6      3.50    5.2

# %%
# diff(): 以上下元素的差異值填入
trans_data = np.log(data).diff().dropna()
trans_data[:5]
# Out:
#         cpi        m1  tbilrate     unemp
# 1  0.005849  0.014215  0.088193 -0.128617
# 2  0.006838 -0.008505  0.215321  0.038466
# 3  0.000681 -0.003565  0.125317  0.055060
# 4  0.005772 -0.002861 -0.212805 -0.074108
# 5  0.000338  0.004289 -0.266946  0.000000

# %%
# plt.scatter()可以繪製散佈圖，標示每一個資料row的 兩個columns的數據分布
plt.scatter(trans_data.m1, trans_data.unemp)
plt.title('Changes in log({0}) vs. log({1})'.format('m1', 'unemp'))

# %%
trans_data.plot.scatter('m1', 'unemp')

# %%
# pandas 提供了 scatter_matrix()函數，方便由DataFrame繪製散佈圖
# 會自動的產生各個columns之間的 scatter diagram
pd.scatter_matrix(trans_data, color = 'k', alpha = 0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A94EAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A9E44A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AA2CE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AA68B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AAB1D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AAF3668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AB42358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AAFEF60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000ABC67F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AC10630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AC4FBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AC9E4E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000ACD5F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AD25080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AD5FD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000ADAF588>]], dtype=object)
